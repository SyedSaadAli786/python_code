# %%
class Person:
    def __init__(self, name , age):
        self.name = name
        self.age = age
    def dislay_person(self):
        print("Name: " , self.name )
        print("Age: " , self.age )

class Student(Person):

    def __init__(self, name, age, roll_no, marks ):
        super().__init__(name,age)
        self.roll_no = roll_no
        self.marks = marks

    def calculte_marks(self):
        marks = self.marks
        if marks >= 80:
            return "A"
        elif marks >= 70:
            return "B"
        else:
            return "Fail"
    def display_student(self):
        self.dislay_person()
        print("Marks: ", self.marks)        
        print("Grade: ", self.calculte_marks())        

class Teacher(Person):
    def __init__(self, name, age, subject, salary):
        super().__init__(name, age)
        self.subject = subject
        self.salary = salary

    def display_teacher(self):
        self.dislay_person()    
        print("Subject:", self.subject)
        print("Salary:", self.salary)

# %%
student1 = Student("Saad", 22, 101, 85)

teacher1 = Teacher("Ahmed", 35, "Python", 80000)

print("----- Student Record -----")
student1.display_student()

print("\n----- Teacher Record -----")
teacher1.display_teacher()
# Out:
# ----- Student Record -----
# Name:  Saad
# Age:  22
# Marks:  85
# Grade:  A
#
# ----- Teacher Record -----
# Name:  Ahmed
# Age:  35
# Subject: Python
# Salary: 80000
